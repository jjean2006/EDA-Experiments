# %% [markdown]
# <a href="https://colab.research.google.com/github/jjean2006/EDA-Experiments/blob/main/Experiment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
import pandas as pd
df1 = pd.read_csv("/content/drive/MyDrive/EDA LAB L41+L42 (2026-2027)/PPT/LAB/DATASETs/AirPassengers.csv")
df1.head()
df1.tail()
print(df1)

df2 = pd.read_csv('/content/drive/MyDrive/EDA LAB L41+L42 (2026-2027)/PPT/LAB/DATASETs/drug200.csv')

vertical_concat = pd.concat([df1, df2], ignore_index=True)
print("Vertical Concatenation:")
print(vertical_concat)

horizontal_concat = pd.concat([df1, df2], axis=1)
print("\nHorizontal Concatenation:")
print(horizontal_concat)

print(df1.describe())
print(df1['#Passengers'].value_counts())

print(df1.stack())
print(df1.unstack())
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]
# Vertical Concatenation:
#        Month  #Passengers   Age  Sex      BP Cholesterol  Na_to_K   Drug
# 0    1949-01        112.0   NaN  NaN     NaN         NaN      NaN    NaN
# 1    1949-02        118.0   NaN  NaN     NaN         NaN      NaN    NaN
# 2    1949-03        132.0   NaN  NaN     NaN         NaN      NaN    NaN
# 3    1949-04        129.0   NaN  NaN     NaN         NaN      NaN    NaN
# 4    1949-05        121.0   NaN  NaN     NaN         NaN      NaN    NaN
# ..       ...          ...   ...  ...     ...         ...      ...    ...
# 339      NaN          NaN  56.0    F     LOW        HIGH   11.567  drugC
# ...
